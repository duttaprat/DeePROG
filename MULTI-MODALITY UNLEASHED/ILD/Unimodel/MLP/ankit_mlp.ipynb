# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
# Out:
# 1.0.1.post2
# True

# %%
from torch import nn
import numpy as np
from torch import nn
import torch.nn.functional as F

# %%
import os
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split

# %%
seed=4
df=pd.read_csv("../../data/ILD.csv")
no_of_rows,no_of_cols=df.shape
print (no_of_rows,no_of_cols)
df.head()
# Out:
# 18144 31
#          id_ref gen_name       v1       v2       v3       v4       v5  \
# 0        117_at    HSPA6  9.30153  7.76291  8.22701  6.53772  7.07184
# 1  1552256_a_at   SCARB1  9.23851  8.72522  9.64837  8.57190  8.65099
# 2  1552264_a_at    MAPK1  7.66847  6.33183  7.63279  6.88978  5.22121
# 3    1552266_at   ADAM32  2.93300  3.21916  2.90779  2.92548  3.00375
# 4    1552269_at  SPATA17  3.28760  3.28215  3.23187  4.13789  3.28960
#
#         v6       v7       v8  ...      v20      v21      v22       v23  \
# 0  6.52416  8.44547  9.12909  ...  7.65737  7.57223  6.32249   8.68267
# 1  7.83348  9.23631  7.48586  ...  7.62708  8.58799  8.29108  10.14260
# 2  7.19912  6.05334  7.88042  ...  6.59411  6.97608  7.01681   6.22543
# 3  2.92548  3.48475  2.90148  ...  2.87648  2.88108  2.88388   3.70028
# 4  3.67241  3.32874  3.35934  ...  3.26634  3.26095  3.24001   3.30414
#
#        v24      v25      v26      v27      v28      v29
# 0  7.96583  7.06424  7.83115  7.10093  8.22633  7.02261
# 1  8.76561  8.72965  9.03287  8.62517  9.47877  8.99476
# 2  7.47331  5.71312  6.74352  6.95748  6.91755  6.51478
# 3  2.89574  2.89005  2.80739  2.86702  2.92548  2.96130
# 4  3.26701  3.22343  3.18599  3.27333  3.26745  3.29148
#
# [5 rows x 31 columns]

# %%
header_of_pd=['v'+str(i+1) for i in range(no_of_cols-2)]
X=np.array(df[header_of_pd])
print(X.shape)
# Out:
# (18144, 29)

# %%
fil=open('../../data/labels_ILD.txt','r')
tmp=list()
for line in fil:
	tmp.append(int(line))

Y=np.array(tmp)

# %%
augmented_X=[]
augmented_Y=[]
a=0
b=0
c=0
d=0
choice=0
t=0
for i in Y:
    if i==0:
        
        choice=1
        a=a+choice
    elif i==1:
        choice=2
        b=b+choice
        
    elif i==2:
        choice=4
        c=c+choice
    for u in range(choice):
        augmented_X.append(X[t])
        augmented_Y.append(Y[t])
    t=t+1
    
print(a,b,c,d)
augmented_X=np.array(augmented_X)
augmented_Y=np.array(augmented_Y)
# Out:
# 9947 10952 10884 0

# %%
X_train,X_test,Y_train,Y_test=train_test_split(augmented_X,augmented_Y,test_size=0.20,random_state=2)
print(X_test.shape)
# Out:
# (6357, 29)

# %%
class Net(torch.nn.Module):
    def __init__(self, n_feature,out_features):
        super(Net, self).__init__()
        self.hidden1 = torch.nn.Linear(n_feature,300)
        self.hidden2 = torch.nn.Linear(300,100)
        self.hidden3 = torch.nn.Linear(100,50)
        self.hidden4 = torch.nn.Linear(50,10)
        self.predict = torch.nn.Linear(10,out_features)
        self.bn1 = nn.BatchNorm1d(num_features=300)
        self.bn2 = nn.BatchNorm1d(num_features=100)
        self.bn3 = nn.BatchNorm1d(num_features=50)
        self.bn4 = nn.BatchNorm1d(num_features=10)
        self.dropout=nn.Dropout(0.2)

        
    def forward(self, x):
        x = F.relu(self.hidden1(x))
        x=self.bn1(x)
        x=self.dropout(x)
        x = F.relu(self.hidden2(x))
        x=self.bn2(x)
        x =F.relu(self.hidden3(x))
        x=self.bn3(x)
        x=self.dropout(x)
        x =F.relu(self.hidden4(x))
        x=self.bn4(x)
        x=F.relu(self.predict(x))
        return x
def accurate():
    total = X_test.shape[0]
    x_test=torch.tensor(X_test,dtype=torch.float)
    y_test=torch.tensor(Y_test,dtype=torch.long)
    outputs = MP(x_test)
    _, predicted = torch.max(outputs.data, 1)
    correct = (predicted.cpu() == y_test).sum()
    confusion_matrix = torch.zeros(3, 3)
    print('Accuracy of the network on the test data: %d %%' % (100 * correct / total))
    for t, p in zip(y_test.view(-1), predicted.view(-1)):
        confusion_matrix[t.long(), p.long()] += 1
    print(confusion_matrix)

# %%
MP=Net(29,3)

inp=torch.tensor(X_test,dtype=torch.float)

criterion = nn.CrossEntropyLoss()
target=torch.tensor(np.zeros((4)),dtype=torch.long)
#output = criterion(mid, target)

optimizer = torch.optim.Adam(MP.parameters(), lr = 0.0001)

epoch=100
batch=10

sizez=(np.array(X_train)).shape[0]
print (sizez)
# Out:
# 25426

# %%
epoch=10000
def trainz():
    no_batch=(sizez//batch)
    for i in range (epoch):
        start=0
        NET_LOSS=0
        for j in range(no_batch+1):

            stop=start+batch
            if(stop<=sizez):
                  stop=stop
            else:
                  stop=sizez
        if start>=sizez:
              break

        x_batch=torch.tensor(X_train[start:stop],dtype=torch.float)
        y_batch=torch.tensor(Y_train[start:stop],dtype=torch.long)

        out_batch=MP(x_batch)
        LOSS_BATCH=criterion(out_batch,y_batch)
        optimizer.zero_grad()
        LOSS_BATCH.backward()
        optimizer.step()
        NET_LOSS=NET_LOSS+LOSS_BATCH
#       print(str(LOSS_BATCH)+"___"+str(j))
        start=start+batch
        if start>=sizez or start>stop:
              break
        accurate()
        print(NET_LOSS)

trainz()
# Out:
# Accuracy of the network on the test data: 39 %
# tensor([[ 923.,  266.,  767.],
#         [ 746.,  137., 1300.],
#         [ 676.,   77., 1465.]])
# tensor(1.0493, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 40 %
# tensor([[ 959.,  270.,  727.],
#         [ 730.,  132., 1321.],
#         [ 655.,   99., 1464.]])
# tensor(1.0629, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 41 %
# tensor([[ 987.,  248.,  721.],
#         [ 647.,  173., 1363.],
#         [ 663.,   78., 1477.]])
# tensor(1.0817, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 42 %
# tensor([[1057.,  244.,  655.],
#         [ 640.,  169., 1374.],
#         [ 659.,   79., 1480.]])
# tensor(1.0825, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 43 %
# tensor([[1102.,  223.,  631.],
#         [ 560.,  207., 1416.],
#         [ 651.,   82., 1485.]])
# tensor(1.0483, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 44 %
# tensor([[1140.,  230.,  586.],
#         [ 583.,  178., 1422.],
#         [ 647.,   67., 1504.]])
# tensor(1.0990, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 45 %
# tensor([[1183.,  200.,  573.],
#         [ 525.,  181., 1477.],
#         [ 636.,   68., 1514.]])
# tensor(0.9657, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 46 %
# tensor([[1190.,  197.,  569.],
#         [ 505.,  230., 1448.],
#         [ 633.,   80., 1505.]])
# tensor(1.0549, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 46 %
# tensor([[1217.,  220.,  519.],
#         [ 496.,  210., 1477.],
#         [ 582.,   79., 1557.]])
# tensor(1.0230, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 47 %
# tensor([[1290.,  181.,  485.],
#         [ 457.,  206., 1520.],
#         [ 636.,   61., 1521.]])
# tensor(1.0379, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 47 %
# tensor([[1281.,  166.,  509.],
#         [ 452.,  201., 1530.],
#         [ 598.,   91., 1529.]])
# tensor(1.0573, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 48 %
# tensor([[1294.,  164.,  498.],
#         [ 455.,  205., 1523.],
#         [ 588.,   70., 1560.]])
# tensor(1.0029, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 49 %
# tensor([[1355.,  155.,  446.],
#         [ 388.,  239., 1556.],
#         [ 589.,   68., 1561.]])
# tensor(1.0676, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 48 %
# tensor([[1349.,  155.,  452.],
#         [ 388.,  211., 1584.],
#         [ 608.,   69., 1541.]])
# tensor(0.9987, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 50 %
# tensor([[1390.,  151.,  415.],
#         [ 419.,  238., 1526.],
#         [ 545.,   71., 1602.]])
# tensor(0.9731, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 50 %
# tensor([[1388.,  153.,  415.],
#         [ 397.,  227., 1559.],
#         [ 581.,   70., 1567.]])
# tensor(1.0483, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 50 %
# tensor([[1394.,  142.,  420.],
#         [ 377.,  251., 1555.],
#         [ 579.,   64., 1575.]])
# tensor(0.9668, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 50 %
# tensor([[1400.,  136.,  420.],
#         [ 399.,  220., 1564.],
#         [ 529.,   67., 1622.]])
# tensor(0.9855, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 51 %
# tensor([[1425.,  143.,  388.],
#         [ 363.,  241., 1579.],
#         [ 557.,   58., 1603.]])
# tensor(0.9506, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 52 %
# tensor([[1462.,  114.,  380.],
#         [ 351.,  253., 1579.],
#         [ 554.,   65., 1599.]])
# tensor(1.0134, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 52 %
# tensor([[1426.,  140.,  390.],
#         [ 367.,  254., 1562.],
#         [ 526.,   62., 1630.]])
# tensor(0.9685, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 53 %
# tensor([[1497.,  117.,  342.],
#         [ 341.,  271., 1571.],
#         [ 518.,   63., 1637.]])
# tensor(1.0000, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 52 %
# tensor([[1443.,  139.,  374.],
#         [ 343.,  239., 1601.],
#         [ 515.,   47., 1656.]])
# tensor(0.9698, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 53 %
# tensor([[1488.,  144.,  324.],
#         [ 322.,  241., 1620.],
#         [ 495.,   76., 1647.]])
# tensor(0.9658, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 53 %
# tensor([[1486.,   97.,  373.],
#         [ 312.,  265., 1606.],
#         [ 535.,   45., 1638.]])
# tensor(0.9761, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 53 %
# tensor([[1515.,  122.,  319.],
#         [ 278.,  259., 1646.],
#         [ 528.,   68., 1622.]])
# tensor(0.9093, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 54 %
# tensor([[1488.,  124.,  344.],
#         [ 293.,  295., 1595.],
#         [ 500.,   61., 1657.]])
# tensor(0.9680, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 54 %
# tensor([[1541.,   87.,  328.],
#         [ 270.,  297., 1616.],
#         [ 499.,   65., 1654.]])
# tensor(0.9424, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 55 %
# tensor([[1560.,   88.,  308.],
#         [ 288.,  320., 1575.],
#         [ 496.,   67., 1655.]])
# tensor(0.9462, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 56 %
# tensor([[1582.,   84.,  290.],
#         [ 274.,  304., 1605.],
#         [ 481.,   61., 1676.]])
# tensor(0.9374, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 55 %
# tensor([[1570.,   80.,  306.],
#         [ 242.,  318., 1623.],
#         [ 493.,   70., 1655.]])
# tensor(0.9464, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 56 %
# tensor([[1576.,   68.,  312.],
#         [ 266.,  306., 1611.],
#         [ 448.,   63., 1707.]])
# tensor(0.9417, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 57 %
# tensor([[1627.,   68.,  261.],
#         [ 232.,  346., 1605.],
#         [ 466.,   66., 1686.]])
# tensor(0.9057, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 57 %
# tensor([[1590.,   65.,  301.],
#         [ 220.,  364., 1599.],
#         [ 485.,   60., 1673.]])
# tensor(0.8970, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 57 %
# tensor([[1576.,   95.,  285.],
#         [ 230.,  363., 1590.],
#         [ 465.,   62., 1691.]])
# tensor(0.9225, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 57 %
# tensor([[1575.,   83.,  298.],
#         [ 213.,  378., 1592.],
#         [ 479.,   57., 1682.]])
# tensor(0.9429, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 58 %
# tensor([[1624.,   63.,  269.],
#         [ 220.,  412., 1551.],
#         [ 465.,   62., 1691.]])
# tensor(0.9011, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 58 %
# tensor([[1646.,   59.,  251.],
#         [ 217.,  406., 1560.],
#         [ 475.,   69., 1674.]])
# tensor(0.9408, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 58 %
# tensor([[1629.,   63.,  264.],
#         [ 214.,  395., 1574.],
#         [ 471.,   61., 1686.]])
# tensor(0.9300, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 59 %
# tensor([[1627.,   55.,  274.],
#         [ 213.,  457., 1513.],
#         [ 485.,   56., 1677.]])
# tensor(0.8797, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 59 %
# tensor([[1628.,   58.,  270.],
#         [ 229.,  436., 1518.],
#         [ 446.,   71., 1701.]])
# tensor(0.9506, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 59 %
# tensor([[1618.,   68.,  270.],
#         [ 205.,  460., 1518.],
#         [ 457.,   69., 1692.]])
# tensor(0.8806, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 59 %
# tensor([[1616.,   63.,  277.],
#         [ 202.,  451., 1530.],
#         [ 463.,   67., 1688.]])
# tensor(0.9228, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 60 %
# tensor([[1654.,   52.,  250.],
#         [ 204.,  461., 1518.],
#         [ 440.,   63., 1715.]])
# tensor(0.8868, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 60 %
# tensor([[1634.,   58.,  264.],
#         [ 222.,  496., 1465.],
#         [ 463.,   65., 1690.]])
# tensor(0.9078, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 60 %
# tensor([[1654.,   47.,  255.],
#         [ 205.,  504., 1474.],
#         [ 453.,   66., 1699.]])
# tensor(0.9071, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 59 %
# tensor([[1629.,   52.,  275.],
#         [ 229.,  470., 1484.],
#         [ 485.,   60., 1673.]])
# tensor(0.9397, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 59 %
# tensor([[1632.,   48.,  276.],
#         [ 207.,  504., 1472.],
#         [ 479.,   72., 1667.]])
# tensor(0.8672, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 60 %
# tensor([[1633.,   51.,  272.],
#         [ 218.,  520., 1445.],
#         [ 455.,   59., 1704.]])
# tensor(0.9026, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1655.,   44.,  257.],
#         [ 199.,  560., 1424.],
#         [ 448.,   63., 1707.]])
# tensor(0.9358, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 60 %
# tensor([[1612.,   50.,  294.],
#         [ 220.,  539., 1424.],
#         [ 462.,   77., 1679.]])
# tensor(0.9561, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1646.,   47.,  263.],
#         [ 196.,  562., 1425.],
#         [ 439.,   67., 1712.]])
# tensor(0.8943, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1635.,   45.,  276.],
#         [ 184.,  576., 1423.],
#         [ 449.,   75., 1694.]])
# tensor(0.8665, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1635.,   46.,  275.],
#         [ 206.,  599., 1378.],
#         [ 453.,   68., 1697.]])
# tensor(0.8690, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 62 %
# tensor([[1645.,   51.,  260.],
#         [ 196.,  585., 1402.],
#         [ 438.,   64., 1716.]])
# tensor(0.9137, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1620.,   44.,  292.],
#         [ 211.,  584., 1388.],
#         [ 475.,   54., 1689.]])
# tensor(0.8861, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1634.,   50.,  272.],
#         [ 183.,  620., 1380.],
#         [ 467.,   69., 1682.]])
# tensor(0.8983, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1627.,   44.,  285.],
#         [ 184.,  623., 1376.],
#         [ 470.,   64., 1684.]])
# tensor(0.9055, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 61 %
# tensor([[1637.,   46.,  273.],
#         [ 202.,  626., 1355.],
#         [ 459.,   83., 1676.]])
# tensor(0.8764, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 63 %
# tensor([[1659.,   33.,  264.],
#         [ 176.,  679., 1328.],
#         [ 473.,   63., 1682.]])
# tensor(0.9000, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 63 %
# tensor([[1628.,   38.,  290.],
#         [ 181.,  686., 1316.],
#         [ 475.,   50., 1693.]])
# tensor(0.8525, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 62 %
# tensor([[1650.,   38.,  268.],
#         [ 185.,  666., 1332.],
#         [ 476.,   57., 1685.]])
# tensor(0.9291, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1676.,   29.,  251.],
#         [ 178.,  689., 1316.],
#         [ 455.,   52., 1711.]])
# tensor(0.8906, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 63 %
# tensor([[1624.,   37.,  295.],
#         [ 163.,  712., 1308.],
#         [ 461.,   64., 1693.]])
# tensor(0.8972, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 63 %
# tensor([[1638.,   33.,  285.],
#         [ 196.,  725., 1262.],
#         [ 483.,   60., 1675.]])
# tensor(0.8622, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1666.,   32.,  258.],
#         [ 165.,  737., 1281.],
#         [ 445.,   61., 1712.]])
# tensor(0.8769, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1660.,   31.,  265.],
#         [ 169.,  729., 1285.],
#         [ 469.,   63., 1686.]])
# tensor(0.8629, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1657.,   39.,  260.],
#         [ 181.,  751., 1251.],
#         [ 459.,   61., 1698.]])
# tensor(0.8732, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1657.,   25.,  274.],
#         [ 162.,  769., 1252.],
#         [ 465.,   53., 1700.]])
# tensor(0.8503, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1651.,   26.,  279.],
#         [ 137.,  784., 1262.],
#         [ 488.,   65., 1665.]])
# tensor(0.8970, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 65 %
# tensor([[1678.,   31.,  247.],
#         [ 141.,  777., 1265.],
#         [ 479.,   59., 1680.]])
# tensor(0.8764, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 64 %
# tensor([[1658.,   30.,  268.],
#         [ 165.,  774., 1244.],
#         [ 474.,   58., 1686.]])
# tensor(0.8677, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 65 %
# tensor([[1656.,   22.,  278.],
#         [ 136.,  811., 1236.],
#         [ 436.,   61., 1721.]])
# tensor(0.8799, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 65 %
# tensor([[1668.,   30.,  258.],
#         [ 145.,  790., 1248.],
#         [ 457.,   54., 1707.]])
# tensor(0.8677, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 66 %
# tensor([[1686.,   26.,  244.],
#         [ 135.,  806., 1242.],
#         [ 433.,   59., 1726.]])
# tensor(0.8454, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 65 %
# tensor([[1673.,   29.,  254.],
#         [ 161.,  794., 1228.],
#         [ 469.,   61., 1688.]])
# tensor(0.8676, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 66 %
# tensor([[1702.,   24.,  230.],
#         [ 124.,  813., 1246.],
#         [ 450.,   67., 1701.]])
# tensor(0.8620, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 66 %
# tensor([[1683.,   32.,  241.],
#         [ 128.,  817., 1238.],
#         [ 458.,   46., 1714.]])
# tensor(0.8592, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 66 %
# tensor([[1678.,   31.,  247.],
#         [ 128.,  834., 1221.],
#         [ 448.,   46., 1724.]])
# tensor(0.8630, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 65 %
# tensor([[1675.,   32.,  249.],
#         [ 124.,  796., 1263.],
#         [ 438.,   60., 1720.]])
# tensor(0.8357, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1692.,   22.,  242.],
#         [ 120.,  844., 1219.],
#         [ 435.,   45., 1738.]])
# tensor(0.8444, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1697.,   30.,  229.],
#         [ 131.,  851., 1201.],
#         [ 436.,   56., 1726.]])
# tensor(0.8196, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1677.,   32.,  247.],
#         [ 125.,  859., 1199.],
#         [ 436.,   55., 1727.]])
# tensor(0.8661, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 66 %
# tensor([[1698.,   24.,  234.],
#         [ 121.,  835., 1227.],
#         [ 447.,   65., 1706.]])
# tensor(0.8441, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 66 %
# tensor([[1670.,   32.,  254.],
#         [ 114.,  838., 1231.],
#         [ 443.,   49., 1726.]])
# tensor(0.8292, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1669.,   33.,  254.],
#         [ 132.,  875., 1176.],
#         [ 428.,   67., 1723.]])
# tensor(0.8407, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1708.,   25.,  223.],
#         [ 121.,  848., 1214.],
#         [ 436.,   44., 1738.]])
# tensor(0.8149, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1698.,   31.,  227.],
#         [ 100.,  873., 1210.],
#         [ 416.,   60., 1742.]])
# tensor(0.8706, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 68 %
# tensor([[1696.,   25.,  235.],
#         [ 106.,  899., 1178.],
#         [ 425.,   63., 1730.]])
# tensor(0.8408, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1708.,   21.,  227.],
#         [  96.,  885., 1202.],
#         [ 444.,   64., 1710.]])
# tensor(0.9202, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 68 %
# tensor([[1707.,   22.,  227.],
#         [ 108.,  873., 1202.],
#         [ 424.,   50., 1744.]])
# tensor(0.8274, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1698.,   23.,  235.],
#         [ 116.,  876., 1191.],
#         [ 428.,   56., 1734.]])
# tensor(0.8010, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 67 %
# tensor([[1733.,   23.,  200.],
#         [ 110.,  860., 1213.],
#         [ 433.,   56., 1729.]])
# tensor(0.7964, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 68 %
# tensor([[1700.,   30.,  226.],
#         [ 105.,  891., 1187.],
#         [ 416.,   49., 1753.]])
# tensor(0.8288, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 68 %
# tensor([[1692.,   32.,  232.],
#         [  97.,  881., 1205.],
#         [ 409.,   52., 1757.]])
# tensor(0.8408, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 68 %
# tensor([[1711.,   24.,  221.],
#         [  93.,  905., 1185.],
#         [ 412.,   58., 1748.]])
# tensor(0.8206, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 69 %
# tensor([[1708.,   24.,  224.],
#         [  98.,  940., 1145.],
#         [ 415.,   43., 1760.]])
# tensor(0.8519, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 69 %
# tensor([[1726.,   21.,  209.],
#         [  91.,  936., 1156.],
#         [ 419.,   59., 1740.]])
# tensor(0.8418, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 69 %
# tensor([[1706.,   32.,  218.],
#         [ 102.,  930., 1151.],
#         [ 398.,   45., 1775.]])
# tensor(0.8557, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 69 %
# tensor([[1741.,   22.,  193.],
#         [ 107.,  916., 1160.],
#         [ 407.,   59., 1752.]])
# tensor(0.8377, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 69 %
# tensor([[1701.,   22.,  233.],
#         [  91.,  929., 1163.],
#         [ 401.,   40., 1777.]])
# tensor(0.8490, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1732.,   23.,  201.],
#         [  94.,  994., 1095.],
#         [ 378.,   58., 1782.]])
# tensor(0.8191, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1720.,   26.,  210.],
#         [  96.,  946., 1141.],
#         [ 364.,   60., 1794.]])
# tensor(0.8623, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1723.,   19.,  214.],
#         [  88.,  972., 1123.],
#         [ 377.,   64., 1777.]])
# tensor(0.8314, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1744.,   21.,  191.],
#         [  88.,  983., 1112.],
#         [ 396.,   42., 1780.]])
# tensor(0.8150, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 69 %
# tensor([[1717.,   24.,  215.],
#         [  89.,  942., 1152.],
#         [ 394.,   47., 1777.]])
# tensor(0.8304, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1731.,   23.,  202.],
#         [  91.,  968., 1124.],
#         [ 390.,   49., 1779.]])
# tensor(0.8311, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1737.,   15.,  204.],
#         [  89., 1006., 1088.],
#         [ 393.,   49., 1776.]])
# tensor(0.8421, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1719.,   25.,  212.],
#         [  79., 1021., 1083.],
#         [ 398.,   44., 1776.]])
# tensor(0.8065, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1739.,   17.,  200.],
#         [  76.,  984., 1123.],
#         [ 367.,   45., 1806.]])
# tensor(0.8079, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1709.,   23.,  224.],
#         [  83.,  982., 1118.],
#         [ 394.,   52., 1772.]])
# tensor(0.8135, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 70 %
# tensor([[1722.,   20.,  214.],
#         [  70.,  988., 1125.],
#         [ 369.,   51., 1798.]])
# tensor(0.8108, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1729.,   19.,  208.],
#         [  79., 1013., 1091.],
#         [ 379.,   37., 1802.]])
# tensor(0.7976, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1734.,   23.,  199.],
#         [  74., 1009., 1100.],
#         [ 360.,   50., 1808.]])
# tensor(0.8259, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1738.,   14.,  204.],
#         [  79., 1031., 1073.],
#         [ 369.,   43., 1806.]])
# tensor(0.8231, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1723.,   15.,  218.],
#         [  88., 1009., 1086.],
#         [ 365.,   41., 1812.]])
# tensor(0.8168, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1737.,   19.,  200.],
#         [  70., 1044., 1069.],
#         [ 333.,   58., 1827.]])
# tensor(0.8584, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1751.,   19.,  186.],
#         [  81., 1028., 1074.],
#         [ 372.,   50., 1796.]])
# tensor(0.8306, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1739.,   20.,  197.],
#         [  57., 1037., 1089.],
#         [ 373.,   40., 1805.]])
# tensor(0.8285, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1761.,   15.,  180.],
#         [  62., 1018., 1103.],
#         [ 373.,   40., 1805.]])
# tensor(0.8130, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1739.,   23.,  194.],
#         [  75., 1024., 1084.],
#         [ 382.,   57., 1779.]])
# tensor(0.7913, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1738.,   23.,  195.],
#         [  67., 1040., 1076.],
#         [ 374.,   45., 1799.]])
# tensor(0.8419, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1744.,   23.,  189.],
#         [  65., 1028., 1090.],
#         [ 375.,   45., 1798.]])
# tensor(0.8399, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 71 %
# tensor([[1737.,   20.,  199.],
#         [  61., 1022., 1100.],
#         [ 349.,   51., 1818.]])
# tensor(0.8304, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1758.,   20.,  178.],
#         [  83., 1055., 1045.],
#         [ 362.,   47., 1809.]])
# tensor(0.8224, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1742.,   14.,  200.],
#         [  72., 1047., 1064.],
#         [ 341.,   48., 1829.]])
# tensor(0.8140, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1732.,   22.,  202.],
#         [  79., 1067., 1037.],
#         [ 358.,   50., 1810.]])
# tensor(0.8339, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1721.,   18.,  217.],
#         [  66., 1067., 1050.],
#         [ 351.,   36., 1831.]])
# tensor(0.7844, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1744.,   17.,  195.],
#         [  57., 1060., 1066.],
#         [ 353.,   46., 1819.]])
# tensor(0.8002, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1751.,   18.,  187.],
#         [  57., 1086., 1040.],
#         [ 368.,   40., 1810.]])
# tensor(0.7940, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1726.,   17.,  213.],
#         [  54., 1089., 1040.],
#         [ 365.,   44., 1809.]])
# tensor(0.7960, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1719.,   18.,  219.],
#         [  75., 1052., 1056.],
#         [ 358.,   40., 1820.]])
# tensor(0.8078, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1745.,   13.,  198.],
#         [  67., 1080., 1036.],
#         [ 354.,   39., 1825.]])
# tensor(0.7797, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1730.,   12.,  214.],
#         [  63., 1119., 1001.],
#         [ 352.,   46., 1820.]])
# tensor(0.7919, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1741.,   18.,  197.],
#         [  73., 1073., 1037.],
#         [ 347.,   45., 1826.]])
# tensor(0.8121, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1726.,   16.,  214.],
#         [  59., 1082., 1042.],
#         [ 344.,   42., 1832.]])
# tensor(0.8197, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1706.,   19.,  231.],
#         [  55., 1122., 1006.],
#         [ 358.,   38., 1822.]])
# tensor(0.8170, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 72 %
# tensor([[1734.,   17.,  205.],
#         [  61., 1072., 1050.],
#         [ 347.,   48., 1823.]])
# tensor(0.7856, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1742.,   13.,  201.],
#         [  49., 1124., 1010.],
#         [ 361.,   34., 1823.]])
# tensor(0.7980, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1726.,   15.,  215.],
#         [  58., 1091., 1034.],
#         [ 348.,   44., 1826.]])
# tensor(0.7850, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1742.,   16.,  198.],
#         [  69., 1118.,  996.],
#         [ 331.,   55., 1832.]])
# tensor(0.7772, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1723.,   22.,  211.],
#         [  56., 1084., 1043.],
#         [ 324.,   47., 1847.]])
# tensor(0.7808, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1726.,   15.,  215.],
#         [  49., 1107., 1027.],
#         [ 351.,   43., 1824.]])
# tensor(0.8312, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1731.,   14.,  211.],
#         [  61., 1107., 1015.],
#         [ 343.,   45., 1830.]])
# tensor(0.7945, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1719.,   16.,  221.],
#         [  69., 1097., 1017.],
#         [ 337.,   49., 1832.]])
# tensor(0.7851, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1730.,   17.,  209.],
#         [  51., 1088., 1044.],
#         [ 342.,   49., 1827.]])
# tensor(0.7923, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1761.,   13.,  182.],
#         [  51., 1126., 1006.],
#         [ 329.,   42., 1847.]])
# tensor(0.7820, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1736.,   19.,  201.],
#         [  53., 1096., 1034.],
#         [ 352.,   42., 1824.]])
# tensor(0.8103, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1730.,   19.,  207.],
#         [  54., 1101., 1028.],
#         [ 345.,   48., 1825.]])
# tensor(0.7685, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1723.,   16.,  217.],
#         [  61., 1110., 1012.],
#         [ 339.,   45., 1834.]])
# tensor(0.8224, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1734.,   17.,  205.],
#         [  51., 1135.,  997.],
#         [ 329.,   45., 1844.]])
# tensor(0.7861, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1745.,   16.,  195.],
#         [  50., 1144.,  989.],
#         [ 325.,   57., 1836.]])
# tensor(0.7778, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1750.,   13.,  193.],
#         [  62., 1131.,  990.],
#         [ 340.,   48., 1830.]])
# tensor(0.7718, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1751.,   14.,  191.],
#         [  46., 1159.,  978.],
#         [ 375.,   45., 1798.]])
# tensor(0.7917, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 73 %
# tensor([[1738.,   16.,  202.],
#         [  57., 1143.,  983.],
#         [ 360.,   37., 1821.]])
# tensor(0.7917, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1739.,   10.,  207.],
#         [  52., 1141.,  990.],
#         [ 344.,   42., 1832.]])
# tensor(0.8185, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1736.,   17.,  203.],
#         [  56., 1165.,  962.],
#         [ 329.,   61., 1828.]])
# tensor(0.7953, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1759.,   12.,  185.],
#         [  52., 1174.,  957.],
#         [ 342.,   56., 1820.]])
# tensor(0.8001, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1745.,   16.,  195.],
#         [  65., 1149.,  969.],
#         [ 345.,   43., 1830.]])
# tensor(0.7921, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1742.,   16.,  198.],
#         [  69., 1150.,  964.],
#         [ 339.,   52., 1827.]])
# tensor(0.7911, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1728.,   20.,  208.],
#         [  54., 1177.,  952.],
#         [ 339.,   47., 1832.]])
# tensor(0.7682, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1760.,   14.,  182.],
#         [  49., 1160.,  974.],
#         [ 326.,   50., 1842.]])
# tensor(0.7640, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1729.,   21.,  206.],
#         [  48., 1165.,  970.],
#         [ 331.,   49., 1838.]])
# tensor(0.8137, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1741.,   17.,  198.],
#         [  43., 1155.,  985.],
#         [ 345.,   46., 1827.]])
# tensor(0.7863, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1759.,    9.,  188.],
#         [  55., 1159.,  969.],
#         [ 339.,   50., 1829.]])
# tensor(0.7645, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1760.,   10.,  186.],
#         [  46., 1192.,  945.],
#         [ 338.,   46., 1834.]])
# tensor(0.7574, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1724.,   16.,  216.],
#         [  51., 1175.,  957.],
#         [ 341.,   51., 1826.]])
# tensor(0.7634, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1728.,   16.,  212.],
#         [  55., 1175.,  953.],
#         [ 335.,   48., 1835.]])
# tensor(0.7761, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1738.,   10.,  208.],
#         [  54., 1209.,  920.],
#         [ 325.,   45., 1848.]])
# tensor(0.7795, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1747.,   16.,  193.],
#         [  43., 1207.,  933.],
#         [ 338.,   48., 1832.]])
# tensor(0.7860, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1753.,   14.,  189.],
#         [  46., 1171.,  966.],
#         [ 331.,   39., 1848.]])
# tensor(0.7884, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1729.,   15.,  212.],
#         [  59., 1176.,  948.],
#         [ 359.,   42., 1817.]])
# tensor(0.7649, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1741.,   11.,  204.],
#         [  43., 1198.,  942.],
#         [ 346.,   45., 1827.]])
# tensor(0.7766, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1721.,   13.,  222.],
#         [  55., 1191.,  937.],
#         [ 344.,   42., 1832.]])
# tensor(0.7630, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1729.,   10.,  217.],
#         [  45., 1187.,  951.],
#         [ 336.,   43., 1839.]])
# tensor(0.7640, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1758.,   14.,  184.],
#         [  56., 1175.,  952.],
#         [ 336.,   43., 1839.]])
# tensor(0.7726, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1746.,   14.,  196.],
#         [  46., 1240.,  897.],
#         [ 326.,   44., 1848.]])
# tensor(0.7785, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1732.,   15.,  209.],
#         [  49., 1202.,  932.],
#         [ 333.,   49., 1836.]])
# tensor(0.7528, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1748.,   17.,  191.],
#         [  58., 1191.,  934.],
#         [ 329.,   40., 1849.]])
# tensor(0.7559, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1731.,   13.,  212.],
#         [  54., 1192.,  937.],
#         [ 327.,   50., 1841.]])
# tensor(0.7428, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1713.,    9.,  234.],
#         [  56., 1198.,  929.],
#         [ 330.,   51., 1837.]])
# tensor(0.7777, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1715.,   16.,  225.],
#         [  50., 1204.,  929.],
#         [ 342.,   55., 1821.]])
# tensor(0.7894, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1728.,    8.,  220.],
#         [  48., 1203.,  932.],
#         [ 360.,   49., 1809.]])
# tensor(0.7594, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1743.,   13.,  200.],
#         [  66., 1193.,  924.],
#         [ 323.,   43., 1852.]])
# tensor(0.7522, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1741.,   10.,  205.],
#         [  46., 1180.,  957.],
#         [ 323.,   49., 1846.]])
# tensor(0.7715, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1729.,   17.,  210.],
#         [  36., 1204.,  943.],
#         [ 338.,   39., 1841.]])
# tensor(0.7463, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1743.,   15.,  198.],
#         [  50., 1210.,  923.],
#         [ 327.,   40., 1851.]])
# tensor(0.7536, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1707.,   18.,  231.],
#         [  56., 1188.,  939.],
#         [ 335.,   46., 1837.]])
# tensor(0.7697, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1753.,   10.,  193.],
#         [  44., 1210.,  929.],
#         [ 316.,   40., 1862.]])
# tensor(0.7467, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1742.,   14.,  200.],
#         [  58., 1189.,  936.],
#         [ 330.,   31., 1857.]])
# tensor(0.7767, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1721.,   10.,  225.],
#         [  45., 1241.,  897.],
#         [ 321.,   46., 1851.]])
# tensor(0.7504, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1757.,    7.,  192.],
#         [  42., 1216.,  925.],
#         [ 340.,   48., 1830.]])
# tensor(0.7824, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 74 %
# tensor([[1735.,   15.,  206.],
#         [  48., 1211.,  924.],
#         [ 360.,   37., 1821.]])
# tensor(0.7539, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1745.,   10.,  201.],
#         [  46., 1205.,  932.],
#         [ 303.,   40., 1875.]])
# tensor(0.7330, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1757.,   12.,  187.],
#         [  45., 1202.,  936.],
#         [ 322.,   48., 1848.]])
# tensor(0.7518, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1762.,   10.,  184.],
#         [  42., 1200.,  941.],
#         [ 324.,   47., 1847.]])
# tensor(0.7697, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1744.,   15.,  197.],
#         [  37., 1224.,  922.],
#         [ 311.,   40., 1867.]])
# tensor(0.7685, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1766.,   14.,  176.],
#         [  48., 1215.,  920.],
#         [ 326.,   40., 1852.]])
# tensor(0.7738, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1730.,   14.,  212.],
#         [  56., 1218.,  909.],
#         [ 317.,   55., 1846.]])
# tensor(0.7544, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1758.,   12.,  186.],
#         [  39., 1231.,  913.],
#         [ 340.,   40., 1838.]])
# tensor(0.7621, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1757.,   15.,  184.],
#         [  40., 1229.,  914.],
#         [ 316.,   36., 1866.]])
# tensor(0.7468, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1750.,   10.,  196.],
#         [  41., 1226.,  916.],
#         [ 315.,   30., 1873.]])
# tensor(0.7436, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1757.,   13.,  186.],
#         [  47., 1237.,  899.],
#         [ 304.,   35., 1879.]])
# tensor(0.7663, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1750.,   14.,  192.],
#         [  55., 1246.,  882.],
#         [ 317.,   40., 1861.]])
# tensor(0.7694, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 75 %
# tensor([[1744.,    9.,  203.],
#         [  47., 1250.,  886.],
#         [ 349.,   45., 1824.]])
# tensor(0.7540, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1749.,   12.,  195.],
#         [  43., 1240.,  900.],
#         [ 316.,   28., 1874.]])
# tensor(0.7790, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1754.,   11.,  191.],
#         [  41., 1266.,  876.],
#         [ 313.,   47., 1858.]])
# tensor(0.7513, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1759.,   17.,  180.],
#         [  45., 1259.,  879.],
#         [ 310.,   42., 1866.]])
# tensor(0.7554, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1745.,   12.,  199.],
#         [  45., 1287.,  851.],
#         [ 312.,   43., 1863.]])
# tensor(0.7468, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1750.,   12.,  194.],
#         [  37., 1238.,  908.],
#         [ 297.,   33., 1888.]])
# tensor(0.7356, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1750.,    8.,  198.],
#         [  42., 1244.,  897.],
#         [ 326.,   43., 1849.]])
# tensor(0.7623, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1767.,   13.,  176.],
#         [  43., 1249.,  891.],
#         [ 330.,   42., 1846.]])
# tensor(0.7266, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1761.,   11.,  184.],
#         [  42., 1247.,  894.],
#         [ 308.,   40., 1870.]])
# tensor(0.7702, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1765.,   11.,  180.],
#         [  34., 1259.,  890.],
#         [ 305.,   41., 1872.]])
# tensor(0.7481, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1761.,    9.,  186.],
#         [  41., 1223.,  919.],
#         [ 320.,   44., 1854.]])
# tensor(0.7669, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1757.,   10.,  189.],
#         [  37., 1245.,  901.],
#         [ 311.,   36., 1871.]])
# tensor(0.7332, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1751.,   13.,  192.],
#         [  40., 1269.,  874.],
#         [ 305.,   43., 1870.]])
# tensor(0.7998, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1766.,   17.,  173.],
#         [  37., 1275.,  871.],
#         [ 309.,   45., 1864.]])
# tensor(0.7649, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1758.,    8.,  190.],
#         [  40., 1270.,  873.],
#         [ 313.,   42., 1863.]])
# tensor(0.7721, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1769.,   10.,  177.],
#         [  39., 1303.,  841.],
#         [ 297.,   33., 1888.]])
# tensor(0.7407, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1761.,    8.,  187.],
#         [  47., 1258.,  878.],
#         [ 315.,   43., 1860.]])
# tensor(0.7317, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1760.,    9.,  187.],
#         [  35., 1280.,  868.],
#         [ 319.,   36., 1863.]])
# tensor(0.7470, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1772.,   10.,  174.],
#         [  37., 1271.,  875.],
#         [ 326.,   36., 1856.]])
# tensor(0.7291, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1769.,   10.,  177.],
#         [  39., 1283.,  861.],
#         [ 297.,   40., 1881.]])
# tensor(0.7508, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1763.,    8.,  185.],
#         [  34., 1279.,  870.],
#         [ 302.,   45., 1871.]])
# tensor(0.7364, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1763.,    9.,  184.],
#         [  29., 1308.,  846.],
#         [ 304.,   46., 1868.]])
# tensor(0.7297, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1781.,   10.,  165.],
#         [  37., 1269.,  877.],
#         [ 312.,   41., 1865.]])
# tensor(0.7528, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1774.,   13.,  169.],
#         [  41., 1282.,  860.],
#         [ 291.,   46., 1881.]])
# tensor(0.7547, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 76 %
# tensor([[1756.,   10.,  190.],
#         [  31., 1292.,  860.],
#         [ 340.,   35., 1843.]])
# tensor(0.7307, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1779.,    9.,  168.],
#         [  34., 1285.,  864.],
#         [ 295.,   38., 1885.]])
# tensor(0.7455, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1776.,   15.,  165.],
#         [  32., 1327.,  824.],
#         [ 314.,   36., 1868.]])
# tensor(0.7353, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1766.,    7.,  183.],
#         [  32., 1310.,  841.],
#         [ 286.,   44., 1888.]])
# tensor(0.7327, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1766.,   12.,  178.],
#         [  37., 1270.,  876.],
#         [ 291.,   42., 1885.]])
# tensor(0.7389, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1748.,   11.,  197.],
#         [  38., 1284.,  861.],
#         [ 304.,   43., 1871.]])
# tensor(0.7177, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1763.,    8.,  185.],
#         [  46., 1258.,  879.],
#         [ 297.,   40., 1881.]])
# tensor(0.7363, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1753.,   10.,  193.],
#         [  37., 1322.,  824.],
#         [ 299.,   37., 1882.]])
# tensor(0.7337, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1774.,    8.,  174.],
#         [  34., 1292.,  857.],
#         [ 309.,   39., 1870.]])
# tensor(0.7334, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1753.,    6.,  197.],
#         [  30., 1310.,  843.],
#         [ 304.,   31., 1883.]])
# tensor(0.7399, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1768.,   12.,  176.],
#         [  30., 1331.,  822.],
#         [ 290.,   40., 1888.]])
# tensor(0.7279, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1775.,    8.,  173.],
#         [  35., 1318.,  830.],
#         [ 276.,   45., 1897.]])
# tensor(0.7611, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1768.,    9.,  179.],
#         [  44., 1290.,  849.],
#         [ 302.,   35., 1881.]])
# tensor(0.7248, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1767.,    8.,  181.],
#         [  26., 1329.,  828.],
#         [ 277.,   35., 1906.]])
# tensor(0.7227, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1760.,    7.,  189.],
#         [  36., 1338.,  809.],
#         [ 303.,   37., 1878.]])
# tensor(0.7630, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1780.,    7.,  169.],
#         [  42., 1313.,  828.],
#         [ 282.,   44., 1892.]])
# tensor(0.7394, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1764.,    7.,  185.],
#         [  35., 1325.,  823.],
#         [ 296.,   26., 1896.]])
# tensor(0.7344, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1757.,   11.,  188.],
#         [  30., 1323.,  830.],
#         [ 317.,   40., 1861.]])
# tensor(0.7216, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1773.,   10.,  173.],
#         [  36., 1317.,  830.],
#         [ 303.,   33., 1882.]])
# tensor(0.7312, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1766.,    9.,  181.],
#         [  41., 1327.,  815.],
#         [ 295.,   40., 1883.]])
# tensor(0.7419, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1752.,   10.,  194.],
#         [  33., 1345.,  805.],
#         [ 271.,   37., 1910.]])
# tensor(0.7222, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1777.,    8.,  171.],
#         [  30., 1311.,  842.],
#         [ 286.,   43., 1889.]])
# tensor(0.7252, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1764.,    6.,  186.],
#         [  36., 1332.,  815.],
#         [ 292.,   43., 1883.]])
# tensor(0.7284, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1779.,    5.,  172.],
#         [  29., 1333.,  821.],
#         [ 305.,   38., 1875.]])
# tensor(0.7226, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 77 %
# tensor([[1757.,    5.,  194.],
#         [  38., 1313.,  832.],
#         [ 305.,   42., 1871.]])
# tensor(0.7186, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1778.,   10.,  168.],
#         [  31., 1355.,  797.],
#         [ 298.,   42., 1878.]])
# tensor(0.7269, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1778.,   11.,  167.],
#         [  36., 1344.,  803.],
#         [ 294.,   47., 1877.]])
# tensor(0.7232, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1767.,    8.,  181.],
#         [  32., 1338.,  813.],
#         [ 266.,   54., 1898.]])
# tensor(0.7111, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1769.,   10.,  177.],
#         [  28., 1327.,  828.],
#         [ 298.,   39., 1881.]])
# tensor(0.7380, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1783.,   10.,  163.],
#         [  26., 1335.,  822.],
#         [ 302.,   42., 1874.]])
# tensor(0.7237, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1778.,   11.,  167.],
#         [  27., 1325.,  831.],
#         [ 282.,   32., 1904.]])
# tensor(0.7428, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1779.,    6.,  171.],
#         [  31., 1343.,  809.],
#         [ 297.,   40., 1881.]])
# tensor(0.7185, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1767.,   10.,  179.],
#         [  40., 1342.,  801.],
#         [ 306.,   40., 1872.]])
# tensor(0.7556, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1755.,   13.,  188.],
#         [  34., 1366.,  783.],
#         [ 305.,   40., 1873.]])
# tensor(0.7148, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1764.,    9.,  183.],
#         [  37., 1370.,  776.],
#         [ 290.,   47., 1881.]])
# tensor(0.7220, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1761.,    9.,  186.],
#         [  26., 1340.,  817.],
#         [ 299.,   39., 1880.]])
# tensor(0.7571, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1786.,    9.,  161.],
#         [  30., 1321.,  832.],
#         [ 295.,   49., 1874.]])
# tensor(0.7208, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1745.,   10.,  201.],
#         [  31., 1352.,  800.],
#         [ 297.,   51., 1870.]])
# tensor(0.7422, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 78 %
# tensor([[1765.,   11.,  180.],
#         [  34., 1348.,  801.],
# ...
#         [  21., 1654.,  508.],
#         [ 171.,  107., 1940.]])
# tensor(0.6047, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1723.,    3.,  230.],
#         [  16., 1648.,  519.],
#         [ 183.,  111., 1924.]])
# tensor(0.6098, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1714.,    5.,  237.],
#         [  15., 1630.,  538.],
#         [ 173.,  109., 1936.]])
# tensor(0.5980, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1712.,    4.,  240.],
#         [  14., 1661.,  508.],
#         [ 166.,  107., 1945.]])
# tensor(0.5838, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1733.,    6.,  217.],
#         [  21., 1637.,  525.],
#         [ 166.,  103., 1949.]])
# tensor(0.5701, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1720.,    4.,  232.],
#         [  22., 1652.,  509.],
#         [ 186.,  109., 1923.]])
# tensor(0.5803, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1723.,    4.,  229.],
#         [  19., 1656.,  508.],
#         [ 175.,  103., 1940.]])
# tensor(0.6057, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1734.,    4.,  218.],
#         [  15., 1644.,  524.],
#         [ 181.,  113., 1924.]])
# tensor(0.5977, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1716.,    2.,  238.],
#         [  17., 1641.,  525.],
#         [ 163.,  105., 1950.]])
# tensor(0.5914, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1730.,    8.,  218.],
#         [  25., 1638.,  520.],
#         [ 182.,  105., 1931.]])
# tensor(0.5871, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1735.,    5.,  216.],
#         [  21., 1635.,  527.],
#         [ 183.,  111., 1924.]])
# tensor(0.5811, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1723.,    6.,  227.],
#         [  19., 1636.,  528.],
#         [ 192.,   99., 1927.]])
# tensor(0.5834, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1.7250e+03, 1.0000e+00, 2.3000e+02],
#         [1.4000e+01, 1.6520e+03, 5.1700e+02],
#         [1.7100e+02, 1.0900e+02, 1.9380e+03]])
# tensor(0.5804, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1729.,    5.,  222.],
#         [  14., 1644.,  525.],
#         [ 177.,   98., 1943.]])
# tensor(0.5936, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1727.,    4.,  225.],
#         [  24., 1667.,  492.],
#         [ 173.,   85., 1960.]])
# tensor(0.5725, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1721.,    3.,  232.],
#         [  14., 1651.,  518.],
#         [ 201.,   96., 1921.]])
# tensor(0.5995, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1705.,    8.,  243.],
#         [  22., 1641.,  520.],
#         [ 161.,  110., 1947.]])
# tensor(0.5976, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1730.,    5.,  221.],
#         [  16., 1632.,  535.],
#         [ 203.,   98., 1917.]])
# tensor(0.6187, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1732.,    3.,  221.],
#         [  10., 1633.,  540.],
#         [ 181.,  117., 1920.]])
# tensor(0.5641, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1736.,    7.,  213.],
#         [  16., 1638.,  529.],
#         [ 167.,  105., 1946.]])
# tensor(0.5807, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1728.,    5.,  223.],
#         [  14., 1635.,  534.],
#         [ 180.,   94., 1944.]])
# tensor(0.5845, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 82 %
# tensor([[1715.,    4.,  237.],
#         [  22., 1625.,  536.],
#         [ 184.,  105., 1929.]])
# tensor(0.5929, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1750.,    7.,  199.],
#         [  13., 1630.,  540.],
#         [ 162.,  101., 1955.]])
# tensor(0.5855, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1721.,    2.,  233.],
#         [  16., 1646.,  521.],
#         [ 177.,  111., 1930.]])
# tensor(0.5841, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1717.,    5.,  234.],
#         [  15., 1664.,  504.],
#         [ 172.,  107., 1939.]])
# tensor(0.5803, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1727.,    5.,  224.],
#         [  18., 1632.,  533.],
#         [ 168.,  127., 1923.]])
# tensor(0.5958, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1722.,    4.,  230.],
#         [  18., 1632.,  533.],
#         [ 170.,  109., 1939.]])
# tensor(0.5647, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1727.,    5.,  224.],
#         [  13., 1654.,  516.],
#         [ 150.,  116., 1952.]])
# tensor(0.5721, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1738.,    5.,  213.],
#         [  12., 1641.,  530.],
#         [ 176.,  116., 1926.]])
# tensor(0.5808, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1727.,    5.,  224.],
#         [  13., 1627.,  543.],
#         [ 186.,   95., 1937.]])
# tensor(0.5852, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1699.,    6.,  251.],
#         [  17., 1652.,  514.],
#         [ 158.,  117., 1943.]])
# tensor(0.5919, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1724.,    7.,  225.],
#         [  17., 1685.,  481.],
#         [ 190.,  109., 1919.]])
# tensor(0.5964, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1713.,    6.,  237.],
#         [  15., 1660.,  508.],
#         [ 178.,  111., 1929.]])
# tensor(0.5806, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1747.,    6.,  203.],
#         [  14., 1651.,  518.],
#         [ 159.,  103., 1956.]])
# tensor(0.5639, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1732.,    4.,  220.],
#         [  18., 1670.,  495.],
#         [ 175.,  108., 1935.]])
# tensor(0.5751, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1725.,    7.,  224.],
#         [  16., 1645.,  522.],
#         [ 174.,  110., 1934.]])
# tensor(0.5945, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1725.,    5.,  226.],
#         [  13., 1668.,  502.],
#         [ 157.,  119., 1942.]])
# tensor(0.5738, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1735.,    4.,  217.],
#         [  11., 1667.,  505.],
#         [ 150.,  107., 1961.]])
# tensor(0.5532, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1718.,    6.,  232.],
#         [  16., 1669.,  498.],
#         [ 160.,  100., 1958.]])
# tensor(0.5955, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1731.,    4.,  221.],
#         [  16., 1670.,  497.],
#         [ 160.,  121., 1937.]])
# tensor(0.5738, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1712.,    5.,  239.],
#         [  16., 1656.,  511.],
#         [ 167.,  113., 1938.]])
# tensor(0.5790, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1732.,    3.,  221.],
#         [   8., 1673.,  502.],
#         [ 173.,  101., 1944.]])
# tensor(0.5626, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1705.,    4.,  247.],
#         [  16., 1676.,  491.],
#         [ 156.,  117., 1945.]])
# tensor(0.5743, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1720.,    4.,  232.],
#         [  10., 1692.,  481.],
#         [ 171.,  121., 1926.]])
# tensor(0.6005, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1728.,    3.,  225.],
#         [  15., 1673.,  495.],
#         [ 176.,  104., 1938.]])
# tensor(0.5936, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1730.,    3.,  223.],
#         [  13., 1668.,  502.],
#         [ 159.,  112., 1947.]])
# tensor(0.5845, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1715.,    5.,  236.],
#         [  18., 1650.,  515.],
#         [ 159.,  126., 1933.]])
# tensor(0.5628, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1705.,    5.,  246.],
#         [  18., 1684.,  481.],
#         [ 169.,  103., 1946.]])
# tensor(0.5759, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1709.,    9.,  238.],
#         [  15., 1690.,  478.],
#         [ 155.,  104., 1959.]])
# tensor(0.5571, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1724.,    3.,  229.],
#         [  13., 1662.,  508.],
#         [ 165.,  102., 1951.]])
# tensor(0.5835, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1726.,    5.,  225.],
#         [  10., 1667.,  506.],
#         [ 168.,  107., 1943.]])
# tensor(0.6016, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1721.,    3.,  232.],
#         [  13., 1670.,  500.],
#         [ 175.,  115., 1928.]])
# tensor(0.5919, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1707.,    2.,  247.],
#         [  15., 1691.,  477.],
#         [ 154.,  106., 1958.]])
# tensor(0.5668, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1729.,    5.,  222.],
#         [  12., 1657.,  514.],
#         [ 179.,  105., 1934.]])
# tensor(0.5632, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1717.,    4.,  235.],
#         [  17., 1655.,  511.],
#         [ 160.,  123., 1935.]])
# tensor(0.5788, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1717.,    2.,  237.],
#         [  17., 1680.,  486.],
#         [ 145.,  101., 1972.]])
# tensor(0.5603, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1705.,    6.,  245.],
#         [  17., 1678.,  488.],
#         [ 172.,  125., 1921.]])
# tensor(0.5626, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1717.,    3.,  236.],
#         [  14., 1666.,  503.],
#         [ 151.,  123., 1944.]])
# tensor(0.5701, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1717.,    4.,  235.],
#         [  18., 1678.,  487.],
#         [ 163.,  107., 1948.]])
# tensor(0.5586, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1719.,    3.,  234.],
#         [  15., 1687.,  481.],
#         [ 159.,  113., 1946.]])
# tensor(0.5748, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1716.,    3.,  237.],
#         [  21., 1671.,  491.],
#         [ 161.,  107., 1950.]])
# tensor(0.5777, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1706.,    5.,  245.],
#         [  14., 1685.,  484.],
#         [ 147.,  126., 1945.]])
# tensor(0.5592, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1714.,    3.,  239.],
#         [  15., 1701.,  467.],
#         [ 166.,  113., 1939.]])
# tensor(0.5614, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1717.,    5.,  234.],
#         [  14., 1720.,  449.],
#         [ 172.,  114., 1932.]])
# tensor(0.5638, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1728.,    5.,  223.],
#         [  11., 1680.,  492.],
#         [ 163.,  109., 1946.]])
# tensor(0.5691, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1713.,    3.,  240.],
#         [  16., 1704.,  463.],
#         [ 183.,  119., 1916.]])
# tensor(0.5611, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 84 %
# tensor([[1719.,    3.,  234.],
#         [  12., 1692.,  479.],
#         [ 166.,  116., 1936.]])
# tensor(0.5534, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1709.,    2.,  245.],
#         [  17., 1684.,  482.],
#         [ 164.,  122., 1932.]])
# tensor(0.5416, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1718.,    7.,  231.],
#         [  20., 1678.,  485.],
#         [ 164.,  113., 1941.]])
# tensor(0.5518, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1722.,    3.,  231.],
#         [   6., 1672.,  505.],
#         [ 181.,  125., 1912.]])
# tensor(0.5511, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1697.,    2.,  257.],
#         [  14., 1665.,  504.],
#         [ 159.,  124., 1935.]])
# tensor(0.5476, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1713.,    4.,  239.],
#         [  14., 1688.,  481.],
#         [ 163.,  121., 1934.]])
# tensor(0.5872, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1.7130e+03, 1.0000e+00, 2.4200e+02],
#         [1.0000e+01, 1.6880e+03, 4.8500e+02],
#         [1.6000e+02, 1.2100e+02, 1.9370e+03]])
# tensor(0.5595, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1713.,    6.,  237.],
#         [  18., 1670.,  495.],
#         [ 167.,  116., 1935.]])
# tensor(0.5645, grad_fn=<AddBackward0>)
# Accuracy of the network on the test data: 83 %
# tensor([[1711.,    3.,  242.],
#         [  10., 1683.,  490.],
#         [ 170.,  116., 1932.]])
# tensor(0.5698, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-69640b6df071> in <module>
#      32         print(NET_LOSS)
#      33
# ---> 34 trainz()
#
# <ipython-input-177-69640b6df071> in trainz()
#      29         if start>=sizez or start>stop:
#      30               break
# ---> 31         accurate()
#      32         print(NET_LOSS)
#      33
#
# <ipython-input-175-1f427a897f7d> in accurate()
#      31     x_test=torch.tensor(X_test,dtype=torch.float)
#      32     y_test=torch.tensor(Y_test,dtype=torch.long)
# ---> 33     outputs = MP(x_test)
#      34     _, predicted = torch.max(outputs.data, 1)
#      35     correct = (predicted.cpu() == y_test).sum()
#
# ~/anaconda2/envs/kaiser/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-175-1f427a897f7d> in forward(self, x)
#      21         x=self.bn2(x)
#      22         x =F.relu(self.hidden3(x))
# ---> 23         x=self.bn3(x)
#      24         x=self.dropout(x)
#      25         x =F.relu(self.hidden4(x))
#
# ~/anaconda2/envs/kaiser/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda2/envs/kaiser/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      74             input, self.running_mean, self.running_var, self.weight, self.bias,
#      75             self.training or not self.track_running_stats,
# ---> 76             exponential_average_factor, self.eps)
#      77
#      78     def extra_repr(self):
#
# ~/anaconda2/envs/kaiser/lib/python3.6/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1621     return torch.batch_norm(
#    1622         input, weight, bias, running_mean, running_var,
# -> 1623         training, momentum, eps, torch.backends.cudnn.enabled
#    1624     )
#    1625
#
# KeyboardInterrupt:

# %%
torch.save(MP.state_dict(), "MLP_ILD_15.pt")
