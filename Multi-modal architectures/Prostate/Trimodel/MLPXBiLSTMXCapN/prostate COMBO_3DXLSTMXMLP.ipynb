# %%
import pandas as pd
import numpy as np
from path import Path
import torch.utils.data as data
from imageio import imread
import os
import torch
import torch.nn as nn
import torchvision.models as models
import torch.nn.functional as F 
import matplotlib.pyplot as plt
# %matplotlib inline 
from torch.utils.data.sampler import SubsetRandomSampler

from PIL import *
import ast

# %%
import numpy as np

class ScaledDotProductAttention(nn.Module):
    ''' Scaled Dot-Product Attention '''
    # given query, key,value it finds the rightful weighted component of v to get the attention applied ouput
    #q,v,k- batch X length of sequence X features or encoding
    #attention sholuld be -batchX7X7
    def __init__(self, temperature, attn_dropout=0.1):
        super().__init__()
        self.temperature = temperature
        self.dropout = nn.Dropout(attn_dropout)
        self.softmax = nn.Softmax(dim=2)

    def forward(self, q, k, v, mask=None):
#         print(k.transpose(1,2).shape)

        attn = torch.bmm(q, k.transpose(1, 2)) 
#         print(attn.shape)
        attn = attn / self.temperature

        if mask is not None:
            attn = attn.masked_fill(mask, -np.inf)

        attn = self.softmax(attn)
        attn = self.dropout(attn)
#         print(str(attn.shape)+" "+str(v.shape))
        output = torch.bmm(attn, v)

        return output, attn
SDP=ScaledDotProductAttention(5)
Ss=SDP(torch.zeros(5,6,100),torch.zeros(5,6,100),torch.zeros(5,6,100))
# print(Ss[0].shape)
class MultiHeadAttention(nn.Module):
    ''' Multi-Head Attention module '''

    def __init__(self, n_head, d_model, d_k, d_v, dropout=0.1):
        super().__init__()

        self.n_head = n_head
        self.d_k = d_k
        self.d_v = d_v

        self.w_qs = nn.Linear(d_model, n_head * d_k)
        self.w_ks = nn.Linear(d_model, n_head * d_k)
        self.w_vs = nn.Linear(d_model, n_head * d_v)
        nn.init.normal_(self.w_qs.weight, mean=0, std=np.sqrt(2.0 / (d_model + d_k)))
        nn.init.normal_(self.w_ks.weight, mean=0, std=np.sqrt(2.0 / (d_model + d_k)))
        nn.init.normal_(self.w_vs.weight, mean=0, std=np.sqrt(2.0 / (d_model + d_v)))

        self.attention = ScaledDotProductAttention(temperature=np.power(d_k, 0.5))
        self.layer_norm = nn.LayerNorm(d_model)

        self.fc = nn.Linear(n_head * d_v, d_model)
        nn.init.xavier_normal_(self.fc.weight)

        self.dropout = nn.Dropout(dropout)


    def forward(self, q, k, v, mask=None):

        d_k, d_v, n_head = self.d_k, self.d_v, self.n_head

        sz_b, len_q, _ = q.size()
        sz_b, len_k, _ = k.size()
        sz_b, len_v, _ = v.size()
#         print(str(sz_b)+"die")

        residual = q

        q = self.w_qs(q).view(sz_b, len_q, n_head, d_k)
        k = self.w_ks(k).view(sz_b, len_k, n_head, d_k)
        v = self.w_vs(v).view(sz_b, len_v, n_head, d_v)

        q = q.permute(2, 0, 1, 3).contiguous().view(-1, len_q, d_k) # (n*b) x lq x dk
        k = k.permute(2, 0, 1, 3).contiguous().view(-1, len_k, d_k) # (n*b) x lk x dk
        v = v.permute(2, 0, 1, 3).contiguous().view(-1, len_v, d_v) # (n*b) x lv x dv
#         print("v-"+str(v.shape))
        if mask is not None:
            mask = mask.repeat(n_head, 1, 1) # (n*b) x .. x ..
        output, attn = self.attention(q, k, v, mask=mask)
#         print(q.shape,k.shape,v.shape)
        output = output.view(n_head, sz_b, len_q, d_v)
        output = output.permute(1, 2, 0, 3).contiguous().view(sz_b, len_q, -1) # b x lq x (n*dv)

        output = self.dropout(self.fc(output))
        output = self.layer_norm(output + residual)

        return output, attn
MHA=MultiHeadAttention(4,15,15,15)
op=MHA(torch.zeros(5,7,15),torch.zeros(5,7,15),torch.zeros(5,7,15))
# print(op[0].shape)
class PositionwiseFeedForward(nn.Module):
    ''' A two-feed-forward-layer module '''

    def __init__(self, d_in, d_hid, dropout=0.1):
        super().__init__()
        self.w_1 = nn.Conv1d(d_in, d_hid, 1) # position-wise
        self.w_2 = nn.Conv1d(d_hid, d_in, 1) # position-wise
        self.layer_norm = nn.LayerNorm(d_in)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        residual = x
        output = x.transpose(1, 2)
#         print("FCC-"+str(output.shape))
#         print("FFC_out-"+str(self.w_1(output).shape))
        output = self.w_2(F.relu(self.w_1(output)))
        output = output.transpose(1, 2)
        output = self.dropout(output)
        output = self.layer_norm(output + residual)
        return output

# %%
class EncoderLayer(nn.Module):
    ''' Compose with two layers '''

    def __init__(self, d_model, d_inner, n_head, d_k, d_v, dropout=0.1):
        super(EncoderLayer, self).__init__()
        self.slf_attn = MultiHeadAttention(
            n_head, d_model, d_k, d_v, dropout=dropout)
        self.pos_ffn = PositionwiseFeedForward(d_model, d_inner, dropout=dropout)

    def forward(self, enc_input, non_pad_mask=None, slf_attn_mask=None):
        enc_output, enc_slf_attn = self.slf_attn(
            enc_input, enc_input, enc_input, mask=slf_attn_mask)
#         print("ENC_o")
#         print(enc_output.shape)


        enc_output = self.pos_ffn(enc_output)


        return enc_output, enc_slf_attn
    
XX=EncoderLayer(15,10,4,10,10)

zz=XX(torch.zeros(5,7,15))
# print("ENc")
# print(zz[0].shape)
# print("start")
class Encoder(nn.Module):
    ''' A encoder model with self attention mechanism. '''

    def __init__(self,n_modality,d_model,n_head,d_k,d_v,dropout,n_layers,d_inner=500):
        #d_model - number of features in input 100 here
        #n_head - number of heads of multihaded attention
        #d_k=d_q=  number of features in query, key
        #d_v = number of features in value whose weighted(attentioned) sum we gonna take
        

        super().__init__()
        self.n_modality=n_modality
#         self.stn=nn.ModuleList([SpatialTransformer(3, (240,240), 8) for _ in range(n_ref)])
        
        self.layer_stack = nn.ModuleList([EncoderLayer(d_model, d_inner, n_head, d_k, d_v, dropout=dropout) 
                                          for _ in range(n_layers)])
        self.em=nn.Linear(32,100)
        #self.em1=nn.Linear(225,100)
        self.fc1=nn.Linear(d_model*n_modality,300)
        self.relu=nn.ReLU()
        self.fc2=nn.Linear(300,100)
        self.fc3=nn.Linear(100,2)
#         self.fc4=nn.Linear(50,3)
        self.bn1 = nn.BatchNorm1d(num_features=300)
        self.bn2 = nn.BatchNorm1d(num_features=100)
        self.softmax=nn.Softmax(1)
        self.dropout = nn.Dropout(dropout)

    def forward(self, embeddings1,embeddings2,embeddings3 ):#mlpxlstmx3d


        
        encodings_total=[embeddings1,embeddings2,self.em(embeddings3)]

        enc_output=torch.stack(encodings_total,0)

        
        enc_output=enc_output.permute(1,0,2)
#         print("encoding_OUTPUT2-"+str(enc_output.shape))

        for enc_layer in self.layer_stack:
            enc_output, enc_slf_attn = enc_layer(enc_output,non_pad_mask=None,slf_attn_mask=None)
           
        
        final_input=enc_output.reshape(enc_output.shape[0],-1)

        final=self.relu(self.fc3(self.bn2(self.relu((self.fc2(self.bn1(self.relu(self.fc1(final_input)))))))))
        
        return(final)

# %%
e1=torch.zeros(4,100)
e2=torch.zeros(4,100)
e3=torch.stack([e1,e2],0)
e3.shape
# Out:
# torch.Size([2, 4, 100])

# %%
feature_set_MLP=pd.read_csv('Prostrate_MLP_features_ankit.csv')
feature_set_3d=pd.read_csv('Ankitprostate_3d.csv')
feature_set_LSTM=pd.read_csv('prostrate_LSTM_features_ankit.csv')
feature_set_3d.head()
# Out:
#   gene_name     tag_0     tag_1     tag_2     tag_3     tag_4     tag_5  \
# 0       vhl -0.004627  0.245317  0.004466  0.069272 -0.003327 -0.263032
# 1   ndufa10  0.275199  0.009126 -0.289780  0.004290  0.173320 -0.012266
# 2     ube4b  0.290513  0.000389 -0.282832  0.000397  0.173428 -0.000026
# 3     foxo3  0.281134  0.000155 -0.286166  0.000090  0.173116 -0.000050
# 4     rap2a  0.000149  0.245117 -0.000038  0.066403 -0.000030 -0.267965
#
#       tag_6     tag_7     tag_8  ...    tag_22    tag_23    tag_24    tag_25  \
# 0 -0.003749  0.251758 -0.003560  ...  0.003328 -0.229637  0.004711  0.266983
# 1  0.259847  0.010369  0.283457  ... -0.258688 -0.011406 -0.293413  0.009331
# 2  0.258021 -0.000054  0.284236  ... -0.266636 -0.000551 -0.294954  0.000467
# 3  0.261762  0.000328  0.288521  ... -0.266013 -0.000130 -0.291289  0.000215
# 4 -0.000021  0.249047  0.000241  ... -0.000095 -0.223775  0.000131  0.271736
#
#      tag_26    tag_27    tag_28    tag_29    tag_30    tag_31
# 0 -0.003079  0.228596  0.003680 -0.258568 -0.003935  0.195633
# 1  0.251243  0.009058 -0.211729 -0.013103  0.264524  0.007954
# 2  0.244364  0.000293 -0.203645 -0.000146  0.275976  0.000081
# 3  0.253075  0.000154 -0.203884 -0.000096  0.268459 -0.000015
# 4 -0.000234  0.235593  0.000200 -0.267288  0.000179  0.193028
#
# [5 rows x 33 columns]

# %%
feature_set_MLP.head()
# Out:
#   gene_name      tag_0      tag_1  tag_2      tag_3      tag_4  tag_5  \
# 0       vhl   0.000000   0.000000    0.0  22.241405   0.000000    0.0
# 1      smox   0.000000   0.000000    0.0   0.000000   0.000000    0.0
# 2    znf148   0.000000   0.000000    0.0  21.678095   0.000000    0.0
# 3    map4k2  20.404165  23.852463    0.0   0.000000  43.247234    0.0
# 4     mapk4  42.203545  52.076824    0.0   0.000000  89.526337    0.0
#
#        tag_6      tag_7       tag_8  ...    tag_90     tag_91  tag_92  tag_93  \
# 0   0.000000   0.000000    0.000000  ...  0.000000   0.000000     0.0     0.0
# 1   0.000000   0.000000    7.911898  ...  0.000000   0.000000     0.0     0.0
# 2   0.000000   0.000000    0.000000  ...  0.000000   0.000000     0.0     0.0
# 3  31.033705   0.203660   56.684559  ...  0.000000  18.108454     0.0     0.0
# 4  67.578827  10.026752  108.900192  ...  3.838364  40.393089     0.0     0.0
#
#    tag_94     tag_95     tag_96     tag_97      tag_98     tag_99
# 0     0.0   0.000000   0.000000   0.000000    0.000000  10.266189
# 1     0.0   0.000000   0.000000   0.000000   12.720570   0.000000
# 2     0.0   0.000000   0.000000   0.000000    0.000000  10.640351
# 3     0.0  28.755461   5.603198  13.697145   63.017044   0.000000
# 4     0.0  57.628872  18.609310  32.895622  120.597061   0.000000
#
# [5 rows x 101 columns]

# %%
header_of_MLP=['tag_'+str(i) for i in range(feature_set_MLP.shape[1]-1)]
features_MLP=np.array(feature_set_MLP[header_of_MLP])
gene_MLP=feature_set_MLP['gene_name']
print(features_MLP.shape)
print(len(gene_MLP))
# Out:
# (2424, 100)
# 2424

# %%
dictionary_MLP={}
u=0
for gn in gene_MLP:
    dictionary_MLP[gn]=features_MLP[u]
    u=u+1

# %%
header_of_3d=['tag_'+str(i) for i in range(feature_set_3d.shape[1]-1)]
features_3d=np.array(feature_set_3d[header_of_3d])
gene_3d=feature_set_3d['gene_name']
print(features_3d.shape)
print(len(gene_3d))
# Out:
# (723, 32)
# 723

# %%
dictionary_3d={}
u=f=0
for gn in gene_3d:
    if gn in dictionary_3d.keys():
#         print(gn)
        f=f+1
    dictionary_3d[gn]=features_3d[u]
    u=u+1
print(u)
# Out:
# 723

# %%
print(len(dictionary_3d.keys()))
# Out:
# 676

# %%
header_of_lstm=['tag_'+str(i) for i in range(feature_set_LSTM.shape[1]-1)]
features_lstm=np.array(feature_set_LSTM[header_of_lstm])
gene_lstm=feature_set_LSTM['gene_name']
print(features_lstm.shape)
print(len(gene_lstm))
# Out:
# (1763, 100)
# 1763

# %%
dictionary_lstm={}
u=f=0
for gn in gene_lstm:
    if gn in dictionary_lstm.keys():
#         print(gn)
        f=f+1
    dictionary_lstm[gn]=features_lstm[u]
    u=u+1
print(u)
# Out:
# 1763

# %%
fil=open('../../Multi-modality/Model/Prostrate/uni model/MLP/Labels_prostate.txt','r')
tmp=list()
for line in fil:
	tmp.append(int(line))

label_PROSTATE=np.array(tmp)
print(label_PROSTATE.shape)
# Out:
# (2424,)

# %%
class Sequenceloader(data.Dataset):
    def __init__(self,GN,label,Feat):
        self.gene_names=GN
        self.features_mlp=Feat
        self.label=label
        self.coincdgene_name=[]
        self.coincidfeature_lstm=[]
        self.coincidfeature_3d=[]
        self.coincidfeature_mlp=[]
        self.coincidlabel=[]
        for i in range(len(self.gene_names)):
            u=self.gene_names[i]
            if u in dictionary_3d.keys() and u in dictionary_lstm.keys():
                
                if np.array(self.label[i])==2:
                    ch=3
                else:
                    ch=1
                    
                for jj in range(ch):
                    self.coincdgene_name.append(u)
                    self.coincidfeature_lstm.append(dictionary_lstm[u])
                    self.coincidfeature_3d.append(dictionary_3d[u])
                    self.coincidlabel.append(self.label[i])
                    self.coincidfeature_mlp.append(self.features_mlp[i])
        
        
    
    def __len__(self):
#         print(len(self.dataset))
        return len(self.coincdgene_name)       

    def __getitem__(self, index):
         return np.array(self.coincidfeature_mlp[index]),np.array(self.coincidfeature_lstm[index]),np.array(self.coincidfeature_3d[index]),np.array(self.coincidlabel[index])
#         print(self.dataset['gen_name'][index])          
#         try:
           
#         except :
            
total_set=Sequenceloader(gene_MLP,label_PROSTATE,features_MLP)  
a=b=c=0
for x1,x2,x3,z in total_set:
    if(z==0):
        a=a+1
    elif z==1:
        b=b+1
    else:
        c=c+1
print(a,b,c)
# Out:
# 309 414 0

# %%
batch_size = 4
validation_split = .2
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(total_set)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(total_set, batch_size=batch_size, 
                                           sampler=train_sampler,drop_last=True)
validation_loader = torch.utils.data.DataLoader(total_set, batch_size=batch_size,
                                                sampler=valid_sampler,drop_last=True)

# %%
for a,b,c,d in train_loader:
    print(a.shape,b.shape,c.shape,d.shape)
# Out:
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])
# torch.Size([4, 100]) torch.Size([4, 100]) torch.Size([4, 32]) torch.Size([4])

# %%
def test(test_loader,model):

    total_imgs=0;
    total_corrects=0
    u=0
    nb_classes=2
    confusion_matrix = torch.zeros(nb_classes, nb_classes)
    for i1,i2,i3,label in test_loader:
                

        output=model(i1.to(device).float(),i2.to(device).float(),i3.to(device).float())
        total_imgs=total_imgs+label.shape[0]
        z=torch.max(output,1)[1]==label.to(device)
        _, preds = torch.max(output, 1)
#         print(output.shape)
 
        num_corrects=torch.sum(z)
        total_corrects=total_corrects+num_corrects
        for t, p in zip(label.view(-1), preds.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1


        u=u+1
    
    
    print(confusion_matrix)
    return(total_corrects,total_imgs)

# %%
device='cuda:7'
model_3dXLSTMXMLP=Encoder(3,100,4,300,300,True,4).to(device)
#model_3dXLSTMXMLP.load_state_dict(torch.load(Path('1AnkitPROSTATE_COMBO_3DXLSTMXMLP.pt')))
uz=vz=torch.rand(4,100).to(device)
# model_3dXMLP(uz,vz).shape

# %%
# model.load_state_dict(torch.load(Path('currentz_m1_epoch.pt')))
optim_params = [
    {'params': model_3dXLSTMXMLP.parameters(), 'lr': 0.0001}
]
optimizer = torch.optim.Adam(optim_params)
criterion = nn.CrossEntropyLoss()

# %%
epoch=10000
for i in range(epoch):
    torch.save(model_3dXLSTMXMLP.state_dict(), '1AnkitPROSTATE_COMBO_3DXLSTMXMLP.pt')
    print("Accuracy-"+str(test(validation_loader,model_3dXLSTMXMLP)))
    total_loss=0
    for inp1,inp2,inp3,lab in train_loader:

        

        output=model_3dXLSTMXMLP(inp1.to(device).float(),inp2.to(device).float(),inp3.to(device).float())

        loss_batch=criterion(output,lab.to(device))/4
        optimizer.zero_grad()  
        loss_batch.backward()
        optimizer.step()
        total_loss+=loss_batch
       
    print(total_loss)
# Out:
# tensor([[35., 28.],
#         [53., 28.]])
# Accuracy-(tensor(63, device='cuda:7'), 144)
# tensor(19.2510, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [17., 64.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(16.0100, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [17., 64.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(14.2550, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[49., 14.],
#         [18., 63.]])
# Accuracy-(tensor(112, device='cuda:7'), 144)
# tensor(13.8637, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[49., 14.],
#         [16., 65.]])
# Accuracy-(tensor(114, device='cuda:7'), 144)
# tensor(14.1299, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [13., 68.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(13.0538, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [15., 66.]])
# Accuracy-(tensor(118, device='cuda:7'), 144)
# tensor(12.4005, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(12.9766, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(12.5598, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(12.3735, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [13., 68.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(11.4918, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 7., 74.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(11.2258, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [14., 67.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(12.5749, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(11.7952, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(11.6849, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(11.5028, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [14., 67.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(11.5365, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [11., 70.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(11.0695, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [15., 66.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(10.7559, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [13., 68.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(11.0530, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[48., 15.],
#         [11., 70.]])
# Accuracy-(tensor(118, device='cuda:7'), 144)
# tensor(11.3548, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [13., 68.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(10.5806, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [13., 68.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(10.6788, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [14., 67.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(11.3798, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [15., 66.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(10.2681, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [12., 69.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(11.1681, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(11.1255, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [21., 60.]])
# Accuracy-(tensor(117, device='cuda:7'), 144)
# tensor(10.2678, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [18., 63.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(10.7000, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [11., 70.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(11.5946, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(11.6410, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [12., 69.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(10.7867, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [12., 69.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(10.3540, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(10.2058, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [12., 69.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(10.2252, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(9.7933, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [13., 68.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(10.9326, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [17., 64.]])
# Accuracy-(tensor(117, device='cuda:7'), 144)
# tensor(10.9864, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [13., 68.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(10.7916, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [16., 65.]])
# Accuracy-(tensor(116, device='cuda:7'), 144)
# tensor(10.5512, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [15., 66.]])
# Accuracy-(tensor(118, device='cuda:7'), 144)
# tensor(10.4221, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [12., 69.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(9.8078, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 9., 72.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(10.9902, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 5., 76.]])
# Accuracy-(tensor(133, device='cuda:7'), 144)
# tensor(9.9756, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(9.6759, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(10.1982, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(10.3940, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [16., 65.]])
# Accuracy-(tensor(118, device='cuda:7'), 144)
# tensor(10.6664, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(10.0525, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [ 8., 73.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(10.2784, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(9.6279, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [14., 67.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(9.8927, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(10.6158, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [11., 70.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(9.4275, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 4., 77.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(9.4472, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(10.2210, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(9.7870, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [12., 69.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(9.8225, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [12., 69.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(9.8094, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(9.6183, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(10.7153, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(9.0493, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(10.3584, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [ 9., 72.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(9.0455, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 7., 74.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(9.5624, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [11., 70.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(8.5501, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(9.9277, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(8.8923, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(9.0597, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(9.0545, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [12., 69.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(10.0513, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(8.5260, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.2865, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(9.5337, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.1509, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 6., 75.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(9.0791, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(9.0009, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(9.2164, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [15., 66.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(9.1522, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [14., 67.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(9.1592, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(8.5796, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.6921, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(9.3377, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(9.9315, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [13., 68.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.3023, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(8.7015, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(8.4381, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [11., 70.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(8.7801, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[48., 15.],
#         [ 9., 72.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(8.7905, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 8., 73.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(9.3098, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(8.8941, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(9.2263, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(9.0876, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(8.1128, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(9.1882, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [12., 69.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(9.4590, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(8.3590, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(8.7036, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(8.8364, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(8.5579, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [10., 71.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(8.6241, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [14., 67.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(9.9003, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 9., 72.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(9.1307, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(8.8769, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 7., 74.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(8.4866, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.6307, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 7., 74.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(8.3896, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(9.6583, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [10., 71.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(9.1060, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(8.5804, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.9694, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 9., 72.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(7.8868, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 9., 72.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(8.8768, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 9., 72.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(8.7755, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [14., 67.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.7501, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [14., 67.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(9.8462, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(8.0517, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.2186, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.8729, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(9.2608, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.8699, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [14., 67.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(8.3685, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [12., 69.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(8.1579, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [12., 69.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(7.8993, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.6841, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.5577, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [10., 71.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(9.0483, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[60.,  3.],
#         [ 7., 74.]])
# Accuracy-(tensor(134, device='cuda:7'), 144)
# tensor(9.0227, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(7.7765, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.5658, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(7.4524, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [16., 65.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(7.7595, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[59.,  4.],
#         [10., 71.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(7.4147, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 8., 73.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(8.4167, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [11., 70.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(8.0876, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 6., 75.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(6.6508, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(7.5608, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(8.8027, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(8.3490, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [13., 68.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(8.1100, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(7.9560, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(8.0958, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.5139, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 7., 74.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(7.6528, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(8.8085, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(7.4650, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[49., 14.],
#         [11., 70.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(7.5824, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [14., 67.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(7.7773, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.9476, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(8.1148, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(7.7607, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [13., 68.]])
# Accuracy-(tensor(118, device='cuda:7'), 144)
# tensor(7.1257, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(7.0503, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(7.2802, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 6., 75.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.7747, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [13., 68.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.0853, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [12., 69.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(6.7721, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.6189, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(7.7042, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.4987, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [13., 68.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(7.5426, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 6., 75.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(8.0402, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 5., 76.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(7.9544, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[49., 14.],
#         [13., 68.]])
# Accuracy-(tensor(117, device='cuda:7'), 144)
# tensor(7.9016, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[49., 14.],
#         [13., 68.]])
# Accuracy-(tensor(117, device='cuda:7'), 144)
# tensor(7.0605, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 7., 74.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(8.0096, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(7.8391, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.0480, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.7016, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.7784, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 6., 75.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(8.0329, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.0329, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.3007, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [12., 69.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(6.9184, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.5095, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(7.2979, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.8747, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [10., 71.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(6.5979, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.0444, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [12., 69.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(6.7029, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(5.6769, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [15., 66.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(6.3405, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(7.3294, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[49., 14.],
#         [11., 70.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(6.7208, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.4645, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.2485, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [14., 67.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(6.2944, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 9., 72.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(6.5960, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [14., 67.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.0865, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.8261, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.6162, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [12., 69.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(6.3009, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.0312, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.3463, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(8.2766, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [13., 68.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(7.1990, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.0457, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.2085, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [13., 68.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.3428, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(6.1024, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(6.5008, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [13., 68.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(6.8069, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(7.3786, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.6519, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(6.6771, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [10., 71.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.6757, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.7795, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [13., 68.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(6.1820, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 5., 76.]])
# Accuracy-(tensor(133, device='cuda:7'), 144)
# tensor(6.1944, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.5438, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [13., 68.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(6.4857, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(6.3956, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 8., 73.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.4837, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(6.3098, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(7.6702, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.1136, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(6.8275, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.1844, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.4866, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [17., 64.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(6.4332, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [14., 67.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(7.1772, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [13., 68.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(6.0144, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.8546, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(6.3162, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.4823, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.9056, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.2961, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(7.0751, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 8., 73.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(6.4725, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 6., 75.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(5.9392, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 9., 72.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(6.2371, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.1879, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[47., 16.],
#         [13., 68.]])
# Accuracy-(tensor(115, device='cuda:7'), 144)
# tensor(7.0599, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(6.1935, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.1818, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 5., 76.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(6.7534, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [10., 71.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(6.0942, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.3675, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.9642, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(5.4638, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [10., 71.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.6349, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(6.0593, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(7.1549, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 8., 73.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(7.1317, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(5.9096, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(6.0806, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.6045, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(5.1749, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(5.6181, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.7095, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.9041, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(5.4842, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.1066, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [11., 70.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(6.2609, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.2072, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.9086, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 4., 77.]])
# Accuracy-(tensor(135, device='cuda:7'), 144)
# tensor(6.0303, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(6.0328, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(7.0031, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 4., 77.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(4.8871, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [11., 70.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.5414, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.2379, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.0916, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [12., 69.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(4.0620, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.3638, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.0048, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.7655, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(5.2729, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.0570, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 6., 75.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(6.2180, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [12., 69.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(5.5866, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 5., 76.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(5.6746, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 8., 73.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(6.0920, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [14., 67.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(6.2113, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.1776, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.5797, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.8837, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(5.8311, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.5667, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.8669, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [12., 69.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.5243, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(5.3002, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 3., 78.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(5.1031, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[59.,  4.],
#         [11., 70.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.3140, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(6.0443, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.5097, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 5., 76.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(4.8715, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.3459, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(7.4426, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.4175, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [13., 68.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.6584, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[59.,  4.],
#         [ 8., 73.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(5.0094, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [14., 67.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(4.8247, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.3982, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(6.6681, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.8305, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(5.4169, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.1074, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [11., 70.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(5.2794, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.1192, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.5939, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [13., 68.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(5.7903, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 6., 75.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(6.3627, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[59.,  4.],
#         [ 7., 74.]])
# Accuracy-(tensor(133, device='cuda:7'), 144)
# tensor(6.5115, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [13., 68.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(4.9629, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(4.3808, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.2641, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(6.5030, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.4569, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.8453, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 8., 73.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.3385, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.2769, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.1681, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [12., 69.]])
# Accuracy-(tensor(119, device='cuda:7'), 144)
# tensor(5.2600, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.5816, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [11., 70.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(5.6102, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.5850, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.6058, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(5.2351, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(5.8093, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 5., 76.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(5.4006, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [ 9., 72.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(5.7774, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 9., 72.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(4.9737, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [11., 70.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.4264, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 8., 73.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.2493, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.0125, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(5.5078, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(5.3498, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.0061, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(6.2243, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 7., 74.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(5.5090, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(5.5281, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(6.0401, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [10., 71.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(5.1809, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.9154, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[50., 13.],
#         [ 9., 72.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(5.9210, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[59.,  4.],
#         [10., 71.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(6.3639, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# ...
# tensor([[58.,  5.],
#         [ 7., 74.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(4.5503, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 5., 76.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(3.5352, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 6., 75.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(4.1330, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [13., 68.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(4.1707, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 9., 72.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.3214, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 5., 76.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(4.6110, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [11., 70.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.6092, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 7., 74.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(3.4583, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 5., 76.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(4.2586, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(4.4414, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(4.2088, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 6., 75.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(3.3585, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [10., 71.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(4.4471, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 9., 72.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(3.9781, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [12., 69.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(3.7610, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 6., 75.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(4.1931, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.9300, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 6., 75.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(3.5603, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [12., 69.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(3.5706, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 8., 73.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.8887, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(3.6191, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 9., 72.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.9815, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.2911, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.7473, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(4.0193, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [13., 68.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(3.8034, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.4406, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [13., 68.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(4.0403, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 9., 72.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.7413, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(2.7345, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 8., 73.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(4.2296, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.4248, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 8., 73.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.6038, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(4.0213, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(3.3706, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(3.9831, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.5978, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 4., 77.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(3.8286, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.2348, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(3.4590, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 8., 73.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.9666, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(3.9595, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.4441, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [11., 70.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.4351, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 5., 76.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.8113, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(2.9765, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 4., 77.]])
# Accuracy-(tensor(133, device='cuda:7'), 144)
# tensor(4.3290, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(4.1212, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 2., 79.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(5.3492, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(4.4254, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 5., 76.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(3.3007, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 5., 76.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(3.8913, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(5.2372, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [13., 68.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(3.9488, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [12., 69.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(3.9901, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [ 7., 74.]])
# Accuracy-(tensor(132, device='cuda:7'), 144)
# tensor(3.8098, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [11., 70.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.8309, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 7., 74.]])
# Accuracy-(tensor(131, device='cuda:7'), 144)
# tensor(4.1544, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.5812, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.4267, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.2143, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.6681, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.1120, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.5875, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.5776, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [16., 65.]])
# Accuracy-(tensor(117, device='cuda:7'), 144)
# tensor(3.9410, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 9., 72.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.3912, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.4947, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 6., 75.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.3003, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 8., 73.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(3.8170, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.5599, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [11., 70.]])
# Accuracy-(tensor(123, device='cuda:7'), 144)
# tensor(3.4862, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[58.,  5.],
#         [11., 70.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.2908, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 9., 72.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.5695, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[59.,  4.],
#         [10., 71.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(3.1930, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [11., 70.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(3.1165, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(3.9906, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [13., 68.]])
# Accuracy-(tensor(122, device='cuda:7'), 144)
# tensor(3.2218, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[51., 12.],
#         [ 8., 73.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(4.6157, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.2235, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 8., 73.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.2425, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [12., 69.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(3.4811, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [10., 71.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.2222, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [10., 71.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(3.0035, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(3.8495, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[57.,  6.],
#         [ 8., 73.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(4.0901, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(2.9958, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 6., 75.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# tensor(4.2226, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(4.3286, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[52., 11.],
#         [ 6., 75.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.1106, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.5457, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(4.8217, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.5374, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 7., 74.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(3.7870, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [10., 71.]])
# Accuracy-(tensor(124, device='cuda:7'), 144)
# tensor(4.5842, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [10., 71.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(4.1714, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [17., 64.]])
# Accuracy-(tensor(120, device='cuda:7'), 144)
# tensor(4.6492, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 9., 72.]])
# Accuracy-(tensor(125, device='cuda:7'), 144)
# tensor(4.2950, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [13., 68.]])
# Accuracy-(tensor(121, device='cuda:7'), 144)
# tensor(3.8415, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 8., 73.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(4.4895, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[54.,  9.],
#         [ 9., 72.]])
# Accuracy-(tensor(126, device='cuda:7'), 144)
# tensor(3.6305, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[55.,  8.],
#         [ 7., 74.]])
# Accuracy-(tensor(129, device='cuda:7'), 144)
# tensor(3.9426, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 6., 75.]])
# Accuracy-(tensor(128, device='cuda:7'), 144)
# tensor(4.3312, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[53., 10.],
#         [ 7., 74.]])
# Accuracy-(tensor(127, device='cuda:7'), 144)
# tensor(3.2364, device='cuda:7', grad_fn=<AddBackward0>)
# tensor([[56.,  7.],
#         [ 7., 74.]])
# Accuracy-(tensor(130, device='cuda:7'), 144)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-993da726ec54> in <module>
#      12         loss_batch=criterion(output,lab.to(device))/4
#      13         optimizer.zero_grad()
# ---> 14         loss_batch.backward()
#      15         optimizer.step()
#      16         total_loss+=loss_batch
#
# ~/anaconda2/envs/kaiser/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/anaconda2/envs/kaiser/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
# !nvidia-smi
tensor([[56.,  7.],
        [ 7., 74.]])
Accuracy-(tensor(130, device='cuda:7'), 144)
# Out:
# Thu May 30 13:48:59 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:04:00.0  On |                  N/A |
# | 56%   73C    P2   180W / 250W |  10666MiB / 11172MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:05:00.0 Off |                  N/A |
# | 32%   56C    P2    74W / 250W |   4404MiB / 11172MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 108...  Off  | 00000000:08:00.0 Off |                  N/A |
# | 63%   75C    P2   157W / 250W |   3002MiB / 11172MiB |     84%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  Off  | 00000000:0A:00.0 Off |                  N/A |
# | 23%   28C    P8    15W / 250W |   1411MiB / 11172MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce GTX 108...  Off  | 00000000:85:00.0 Off |                  N/A |
# | 51%   69C    P2   106W / 250W |   9124MiB / 11172MiB |     62%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce GTX 108...  Off  | 00000000:86:00.0 Off |                  N/A |
# | 23%   39C    P8    17W / 250W |   4263MiB / 11172MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce GTX 108...  Off  | 00000000:89:00.0 Off |                  N/A |
# | 37%   64C    P2   163W / 250W |  10668MiB / 11172MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  GeForce GTX 108...  Off  | 00000000:8A:00.0 Off |                  N/A |
# | 22%   58C    P2   100W / 250W |   1984MiB / 11172MiB |     89%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      5857      G   /usr/lib/xorg/Xorg                            50MiB |
# |    0     29295      C   python                                     10599MiB |
# |    1     45836      C   python3                                     4391MiB |
# |    2      9334      C   python                                      2991MiB |
# |    3     44286      C   ...kamalpcs17/anaconda3_sockeye/bin/python  1249MiB |
# |    3     48834      C   python                                       151MiB |
# |    4      5555      C   ...ratik/anaconda2/envs/kaiser/bin/python3   485MiB |
# |    4     39564      C   ...ratik/anaconda2/envs/kaiser/bin/python3  1611MiB |
# |    4     39861      C   ...ratik/anaconda2/envs/kaiser/bin/python3  2555MiB |
# |    4     41877      C   ...ratik/anaconda2/envs/kaiser/bin/python3  3193MiB |
# |    4     47188      C   python                                      1265MiB |
# |    5     10337      C   python                                       599MiB |
# |    5     14265      C   python                                       599MiB |
# |    5     19728      C   python                                      1399MiB |
# |    5     30447      C   python                                      1655MiB |
# |    6     29296      C   python                                     10649MiB |
# |    7     15244      C   ...ratik/anaconda2/envs/kaiser/bin/python3   545MiB |
# |    7     32118      C   python                                       217MiB |
# |    7     43829      C   /home1/dushyant/anaconda2/bin/python         219MiB |
# |    7     46926      C   ...ratik/anaconda2/envs/kaiser/bin/python3   563MiB |
# |    7     46970      C   ...ratik/anaconda2/envs/kaiser/bin/python3   427MiB |
# +-----------------------------------------------------------------------------+
