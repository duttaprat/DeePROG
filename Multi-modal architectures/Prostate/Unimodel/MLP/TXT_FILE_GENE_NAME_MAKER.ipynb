# %%
import pandas as pd

# %%
gn = pd.read_csv('preprocessed_prostrate.csv')
prostrate_gene_names=list(gn['gen_name'])
print(prostrate_gene_names)
# Out:
# ['VHL', 'SMOX', 'ZNF148', 'MAP4K2', 'MAPK4', 'PBX2', 'TXNRD2', 'CAV1', 'FAM193B', 'SREK1IP1', 'FBXW2', 'IMAGE:795726', 'EMC10', 'XPO7', 'CRTAP', 'IMAGE:430233', 'H6PD', 'NDUFA10', 'LOC283587', 'UBE4B', 'IMAGE:293013', 'PTPRU', 'CEBPG', 'IMAGE:75412', 'FGD4', 'HMGN3', 'FOXO3', 'TK2', 'KDM3A', 'RAP2A', 'SLFNL1-AS1', 'IL33', 'IMAGE:491712', 'IMAGE:795260', 'CEP120', 'LOC100507364', 'DOCK1', 'ARHGAP5-AS1', 'PALMD', 'C7orf60', 'TMEM50B', 'ZNF207', 'IMAGE:43679', 'IMAGE:43705', 'IMAGE:133358', 'HIF1AN', 'SEC22C', 'RPRD1A', 'RNFT1', 'TNNI1', 'ALPI', 'ALPL', 'ACOX3', 'CYP3A5', 'RAB4A', 'WASF1', 'SLC35D1', 'TCF7L2', 'POLR2J2', 'IGF2', 'RAF1', 'DDX26B', 'RSC1A1', 'TRAF3IP2', 'THEMIS2', 'IMAGE:123858', 'LOC100134445', 'IMAGE:296857', 'WNT2', 'JUN', 'SHANK3', 'SH3TC2', 'XPNPEP1', 'CNPY3', 'IMAGE:327239', 'SNTA1', 'ALG11', 'SEC14L5', 'BIRC5', 'CRIPT', 'LOC100134259', 'IMAGE:39963', 'IMAGE:45929', 'IMAGE:288821', 'ZNF516', 'IMAGE:290339', 'BZW1', 'IMAGE:304846', 'IMAGE:503675', 'LOC100216479', 'IM
# ...

# %%
# file_obj=open("untitled.txt","r+")
# file_obj.writelines(prostrate_gene_names)
# Out:
# <_io.TextIOWrapper name='untitled.txt' mode='r+' encoding='UTF-8'>

# %%
with open('untitled.txt', 'w') as f:
    for item in prostrate_gene_names:
        f.write("%s\n" % item)
